# %% [markdown]
# <a href="https://colab.research.google.com/github/noushadkhan01/ML-and-DL-by-SuperDataScience/blob/master/Machine-Learning/Part%202%20-%20Regression/Section%206%20-%20Polynomial%20Regression/Polynomial_Regression_on_Position_salary_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://bit.ly/3028Hi2')
df.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
# Position    10 non-null object
# Level       10 non-null int64
# Salary      10 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 368.0+ bytes

# %% [markdown]
# # Train Model without Position for better visualisation

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
df.columns
# Out:
# Index(['Position', 'Level', 'Salary'], dtype='object')

# %%
df.Position.unique()
# Out:
# array(['Business Analyst', 'Junior Consultant', 'Senior Consultant',
#        'Manager', 'Country Manager', 'Region Manager', 'Partner',
#        'Senior Partner', 'C-level', 'CEO'], dtype=object)

# %%
X = df.drop(['Position', 'Salary'], axis = 1)
X.head(2)
# Out:
#    Level
# 0      1
# 1      2

# %%
X.shape
# Out:
# (10, 1)

# %%
def my_visualisation(X, y, degree, evaluate = 6.5):
  evaluate = np.array([[evaluate]])
  model1 = LinearRegression().fit(X, y)
  poly_feature = PolynomialFeatures(degree = degree)
  X_poly  = poly_feature.fit_transform(X)
  evaluate_poly = poly_feature.transform(evaluate)
  model2 = LinearRegression().fit(X_poly, y)
  plt.figure(figsize = (10, 5))
  plt.subplot(1, 2, 1)
  plt.scatter(X, y, color = 'green')
  plt.plot(X, model1.predict(X), c = 'blue')
  plt.scatter(evaluate, model1.predict(evaluate), c = 'red', marker = 'o')
  plt.title('Linear Regression')
  plt.subplot(1, 2, 2)
  plt.scatter(X, y, color = 'green')
  plt.plot(X, model2.predict(X_poly), c = 'blue')
  plt.scatter(evaluate, model2.predict(evaluate_poly), c = 'red')
  plt.title(f'Polynomial Regression with degree {degree}')
  plt.tight_layout()
  plt.show()

# %%
y = df.Salary
y
# Out:
# 0      45000
# 1      50000
# 2      60000
# 3      80000
# 4     110000
# 5     150000
# 6     200000
# 7     300000
# 8     500000
# 9    1000000
# Name: Salary, dtype: int64

# %%
my_visualisation(X, y, degree = 2)

# %%
my_visualisation(X, y, degree = 3)

# %%
my_visualisation(X, y, degree = 4)

# %%
my_visualisation(X, y, degree = 5)

# %%
my_visualisation(X, y, degree = 6)
